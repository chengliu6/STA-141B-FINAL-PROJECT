# %% [markdown]
# Twitter API
# =========================================

# %% [markdown]
# You don't have to understand this code.

# %%
# !pip install tweepy
# install twitter module for python

# %%
import os 
from pprint import pprint
import json
import tweepy
import numpy as np
import pandas as pd

# %%
#api keys
CONSUMER_KEY = "SYwFy7GtvskvMbHrTHo1vztoF"
CONSUMER_SECRET = "Czwdyk7kuIQqXNilYq5ZaiVYajVFfFPwSUCSSX1P9UielICQSV"
ACCESS_TOKEN = "1443610243972284424-idoK7JG7SK5IQiej8AtQ6gIOM9WaH4"
ACCESS_TOKEN_SECRET = "sQBnwwVcknqrGTbBz7H3aGXkD7kFX70z1sanSD8MJfWC3"


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
county_data = pd.read_csv("county_politics.csv")

# %%
dems = county_data[county_data["majority"]=="Democrat"]
dem_short = dems.sort_values("dem_pct", ascending= False).head() #find 5 highest proportion democrat voting counties
dem_short
# Out:
#            county dem_pct rep_pct  majority        lat        long
# 37  San Francisco  85.26%  12.72%  Democrat  37.779026 -122.419906
# 20          Marin  82.33%  15.79%  Democrat  38.040914 -122.619964
# 0         Alameda  79.83%  17.62%  Democrat  37.609029 -121.899142
# 43     Santa Cruz  78.44%  18.49%  Democrat  37.050096 -121.990591
# 40      San Mateo  77.89%  20.20%  Democrat  37.496904 -122.333057

# %%
reps = county_data[county_data["majority"]=="Republican"]
rep_short = reps.sort_values("rep_pct", ascending= False).head() #find 5 highest proportion democrat voting counties
rep_short
# Out:
#     county dem_pct rep_pct    majority        lat        long
# 17  Lassen  23.24%  74.47%  Republican  40.768558 -120.730998
# 24   Modoc  26.33%  71.19%  Republican  41.545049 -120.743600
# 51  Tehama  31.02%  66.62%  Republican  40.125133 -122.201553
# 44  Shasta  32.28%  65.41%  Republican  40.796512 -121.997919
# 10   Glenn  35.36%  62.52%  Republican  39.591277 -122.377866

# %%
def get_covid_tweets(lat,long):
    tweet_list = []
    response = api.search_tweets("covid",
                                geocode = str(lat) + "," + str(long) + ",100km",
                                count = 10,
                                result_type="recent",
                                lang="en")
    for i in response: 
        tweet_list.append(i.text.split("https")[0])
    
    return tweet_list

# %%
test = get_covid_tweets(39.591277,-122.377866)

# %%
test
# Out:
# ["This graphic shows patients who came to Enloe's outpatient clinic seeking care for COVID-19. They either received c… ",
#  'There are no words that can make this feeling go away 😔 loosing my Tia from COVID… Tia Rest In Peace 🕊',
#  'California legislators propose new slate of COVID-19 vaccine laws ',
#  'Covid-19 on the decline: Miller Report for March 2, ’22 ',
#  'Covid-19: Mendocino County lifts mask mandate ',
#  '@BryanEscalera @AlecOfTheYouth @KameronHandy @JordanGrafter98 @EuroHarden @RealTalk900 @OnBallSteph That was Covid… ',
#  'This chart represents a five-day rolling average for the number of COVID-19 patients hospitalized at Enloe, and spe… ',
#  '@QuartzRx This is why I probably didn’t get covid when my family did. I take all 3 of those every day!',
#  '@queenofvision @POTUS @ChrisDaPlumber5 @DonaldJTrumpJr His inflation is crashing the economy.Lifting stay home mand… ',
#  "@lambypie100 @skyfriend @mippy @FbpeSmike @Sporty_sal @Philsbodydouble I don't think it's too much to ask that peop… "]

# %%
rep_twt = []

for i in range (0,5):
    rep_twt += get_covid_tweets(rep_short.iloc[i,4],rep_short.iloc[i,5]) #search each county for covid tweets
# Out:
# ["@covid_priest @christogrozev @mod_russia Oh, it's been circulating in right-wing American media for almost as long.",
#  'Trucker convoy laps Washington, DC, beltway to protest Covid-19 measures ',
#  'Biden’s ‘test to treat’ covid plan draws praise, questions ',
#  '@Kenny_Wallace My kids dad for covid pneumonia. They sent him home O2 was lower than it should have been. A doctor… ',
#  "At next week's Board of Trustees Meeting, Trustees will hear updates on the Superintendent search, COVID mitigation… ",
#  "A convoy of truckers protesting Covid-19 measures is expected to arrive in the DC area this weekend. Here's what we… ",
#  'NFL and NFL Players Association have agreed to suspend all Covid-19 protocols ',
#  '@robsteinnews I will also say that I am also still trying to NOT get Covid working in a high-risk environment (coll… ',
#  'The Morning at Night: A Virtual Event on Ukraine and Covid',
#  'Surgeon General Calls on Big Tech to Turn Over Covid Misinformation Data',
#  'Trucker convoy laps Washington, DC, beltway to protest Covid-19 measures ',
#  'Genuine question: do we need to do self test or rtk again after being infected with covid-19 and completed our hso?… ',
#  '#Woe to you who accepted the #Pfizer #COVID #vaccine #willingly into #your #bodies. #MyBodyMyChoice right? Or was it?',
#  '#TheNewWorldOrder 75 Years! And you #trust your #government CHD Says Pfizer and FDA Dropped Data Bombshell on COVID… ',
#  '@Kenny_Wallace My kids dad for covid pneumonia. They sent him home O2 was lower than it should have been. A doctor… ',
#  "A convoy of truckers protesting Covid-19 measures is expected to arrive in the DC area this weekend. Here's what we… ",
#  'NFL and NFL Players Association have agreed to suspend all Covid-19 protocols ',
#  'The Morning at Night: A Virtual Event on Ukraine and Covid',
#  'Surgeon General Calls on Big Tech to Turn Over Covid Misinformation Data',
#  'BIDEN ADMINISTRATION ASKS CONGRESS FOR $22.5 BILLION FOR COVID SPENDING -WHITE HOUSE',
#  "This graphic shows patients who came to Enloe's outpatient clinic seeking care for COVID-19. They either received c… ",
#  '@WBizz1 Who knows. Those Covid protocols are impossible to predict. Hopefully this week someone.',
#  "@covid_priest @christogrozev @mod_russia Oh, it's been circulating in right-wing American media for almost as long.",
#  '#Shasta County Dis. 2 Supervisor Tim Garman is sworn in after wining the #recall election &amp; there appear to be roug… ',
#  'Are We Breeding Hellish Covid Monsters? ',
#  '@the_ag_fox_1971 Sorry, climate protest, not CoVid',
#  '@the_ag_fox_1971 This is a performance art piece about CoVid from a couple years back',
#  'There are no words that can make this feeling go away 😔 loosing my Tia from COVID… Tia Rest In Peace 🕊',
#  "@feloneouscat @whittler_e Ok, well you and your partner arent the cdc. I think it's so bizarre when people proclaim… ",
#  '@MarleyK20 @CarlaRK3 Rather than this behavior that floods the pockets of the very people pushing for war can we in… ',
#  '@WBizz1 Who knows. Those Covid protocols are impossible to predict. Hopefully this week someone.',
#  "@covid_priest @christogrozev @mod_russia Oh, it's been circulating in right-wing American media for almost as long.",
#  '#Shasta County Dis. 2 Supervisor Tim Garman is sworn in after wining the #recall election &amp; there appear to be roug… ',
#  'Are We Breeding Hellish Covid Monsters? ',
#  '@the_ag_fox_1971 Sorry, climate protest, not CoVid',
#  '@the_ag_fox_1971 This is a performance art piece about CoVid from a couple years back',
#  "@feloneouscat @whittler_e Ok, well you and your partner arent the cdc. I think it's so bizarre when people proclaim… ",
#  'Trucker convoy laps Washington, DC, beltway to protest Covid-19 measures ',
#  '@MarleyK20 @CarlaRK3 Rather than this behavior that floods the pockets of the very people pushing for war can we in… ',
#  '@BryanEscalera @AlecOfTheYouth @KameronHandy @JordanGrafter98 @EuroHarden @RealTalk900 @OnBallSteph That was Covid… ',
#  "This graphic shows patients who came to Enloe's outpatient clinic seeking care for COVID-19. They either received c… ",
#  'There are no words that can make this feeling go away 😔 loosing my Tia from COVID… Tia Rest In Peace 🕊',
#  'California legislators propose new slate of COVID-19 vaccine laws ',
#  'Covid-19 on the decline: Miller Report for March 2, ’22 ',
#  'Covid-19: Mendocino County lifts mask mandate ',
#  '@BryanEscalera @AlecOfTheYouth @KameronHandy @JordanGrafter98 @EuroHarden @RealTalk900 @OnBallSteph That was Covid… ',
#  'This chart represents a five-day rolling average for the number of COVID-19 patients hospitalized at Enloe, and spe… ',
#  '@QuartzRx This is why I probably didn’t get covid when my family did. I take all 3 of those every day!',
#  '@queenofvision @POTUS @ChrisDaPlumber5 @DonaldJTrumpJr His inflation is crashing the economy.Lifting stay home mand… ',
#  "@lambypie100 @skyfriend @mippy @FbpeSmike @Sporty_sal @Philsbodydouble I don't think it's too much to ask that peop… "]

# %%
rep_twt_df = pd.DataFrame(rep_twt, columns = ["tweet"]) #create dataframe for tweets
rep_twt_df
# Out:
#                                                 tweet
# 0   @covid_priest @christogrozev @mod_russia Oh, i...
# 1   Trucker convoy laps Washington, DC, beltway to...
# 2   Biden’s ‘test to treat’ covid plan draws prais...
# 3   @Kenny_Wallace My kids dad for covid pneumonia...
# 4   At next week's Board of Trustees Meeting, Trus...
# 5   A convoy of truckers protesting Covid-19 measu...
# 6   NFL and NFL Players Association have agreed to...
# 7   @robsteinnews I will also say that I am also s...
# 8   The Morning at Night: A Virtual Event on Ukrai...
# 9   Surgeon General Calls on Big Tech to Turn Over...
# 10  Trucker convoy laps Washington, DC, beltway to...
# 11  Genuine question: do we need to do self test o...
# 12  #Woe to you who accepted the #Pfizer #COVID #v...
# 13  #TheNewWorldOrder 75 Years! And you #trust you...
# 14  @Kenny_Wallace My kids dad for covid pneumonia...
# 15  A convoy of truckers protesting Covid-19 measu...
# 16  NFL and NFL Players Association have agreed to...
# 17  The Morning at Night: A Virtual Event on Ukrai...
# 18  Surgeon General Calls on Big Tech to Turn Over...
# 19  BIDEN ADMINISTRATION ASKS CONGRESS FOR $22.5 B...
# 20  This graphic shows patients who came to Enloe'...
# 21  @WBizz1 Who knows. Those Covid protocols are i...
# 22  @covid_priest @christogrozev @mod_russia Oh, i...
# 23  #Shasta County Dis. 2 Supervisor Tim Garman is...
# 24           Are We Breeding Hellish Covid Monsters?
# 25  @the_ag_fox_1971 Sorry, climate protest, not C...
# 26  @the_ag_fox_1971 This is a performance art pie...
# 27  There are no words that can make this feeling ...
# 28  @feloneouscat @whittler_e Ok, well you and you...
# 29  @MarleyK20 @CarlaRK3 Rather than this behavior...
# 30  @WBizz1 Who knows. Those Covid protocols are i...
# 31  @covid_priest @christogrozev @mod_russia Oh, i...
# 32  #Shasta County Dis. 2 Supervisor Tim Garman is...
# 33           Are We Breeding Hellish Covid Monsters?
# 34  @the_ag_fox_1971 Sorry, climate protest, not C...
# 35  @the_ag_fox_1971 This is a performance art pie...
# 36  @feloneouscat @whittler_e Ok, well you and you...
# 37  Trucker convoy laps Washington, DC, beltway to...
# 38  @MarleyK20 @CarlaRK3 Rather than this behavior...
# 39  @BryanEscalera @AlecOfTheYouth @KameronHandy @...
# 40  This graphic shows patients who came to Enloe'...
# 41  There are no words that can make this feeling ...
# 42  California legislators propose new slate of CO...
# 43  Covid-19 on the decline: Miller Report for Mar...
# 44     Covid-19: Mendocino County lifts mask mandate
# 45  @BryanEscalera @AlecOfTheYouth @KameronHandy @...
# 46  This chart represents a five-day rolling avera...
# 47  @QuartzRx This is why I probably didn’t get co...
# 48  @queenofvision @POTUS @ChrisDaPlumber5 @Donald...
# 49  @lambypie100 @skyfriend @mippy @FbpeSmike @Spo...

# %%
import text2emotion as te
te.get_emotion(rep_twt_df.tweet[4])
# Out:
# {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}

# %%
happy = []
angry= []
surprise = []
sad = []
fear = []

# create lists to store int values of each emotion

for text in rep_twt_df.tweet:
    emotions = te.get_emotion(text)
    happy.append(emotions["Happy"])
    happy.append(emotions["Angry"])
    happy.append(emotions["Surprise"])
    happy.append(emotions["Sad"])
    happy.append(emotions["Fear"]) #append values for each emotion to the lists

# %%
rep_twt_master = " ".join(rep_twt)
te.get_emotion(rep_twt_master)
# Out:
# {'Happy': 0.07, 'Angry': 0.1, 'Surprise': 0.23, 'Sad': 0.19, 'Fear': 0.41}
